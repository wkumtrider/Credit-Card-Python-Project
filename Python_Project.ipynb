# %%
import pandas as pd
import os
os.getcwd()
# Out:
# 'C:\\Users\\Jason\\Documents\\Python\\Python_Project1'

# %%
# read file into dataframe
report = pd.read_csv("C:\\Users\Jason\Documents\Finances\Jan 2019.csv")

# %%
report
# Out:
#    Transaction Date  Post Date               Description           Category  \
# 0         1/29/2019  1/31/2019  TOTAL WINE AND MORE 2103       Food & Drink
# 1         1/28/2019  1/29/2019                LA FITNESS  Health & Wellness
# 2         1/28/2019  1/29/2019         MCALISTER'S #1079       Food & Drink
# 3         1/28/2019  1/29/2019    TARGET        00007807           Shopping
# 4         1/26/2019  1/27/2019    TARGET        00007807           Shopping
# ..              ...        ...                       ...                ...
# 70         1/5/2019   1/7/2019               KROGER #379          Groceries
# 71         1/4/2019   1/6/2019               KROGER #379          Groceries
# 72         1/1/2019   1/2/2019         KROGER FUEL #8379                Gas
# 73         1/1/2019   1/2/2019         KROGER FUEL #8379                Gas
# 74       12/30/2018   1/1/2019    MEIJER INC #160    Q01          Groceries
#
#     Type  Amount  Unnamed: 6
# ...
